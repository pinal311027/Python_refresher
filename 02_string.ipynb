# %%
#define string
name = "pinal"
greet = "hello"
message = """this is 
multiline string"""
print(name)
print(greet)
print(message)
# Out:
# pinal
# hello
# this is
# multiline string

# %%
#string slicing and indexing
text = "I love Python"
print(text[0])
print(text[-1])
print(text[0:4])
print(text[:8])
print(text[5:])
# Out:
# I
# n
# I lo
# I love P
# e Python

# %%
#string methods

str1 = " I Love Python "
str2 = "aaa"
print(str1.lower())
print(str1.upper())
print(str1.strip())
print(str1.replace("I","We"))
print(str1.split())
print(str1.join(str2))
print(str1.find("o"))
print(str1.count("o"))
print(str1.isdigit())
print(str2.isalpha())
print(str.isalnum())
# Out:
#  i love python
#  I LOVE PYTHON
# I Love Python
#  We Love Python
# ['I', 'Love', 'Python']
# a I Love Python a I Love Python a
# 4
# 2
# False
# True
# False
