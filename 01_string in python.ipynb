# %%
#variable in python
name = "pinal"
age = 21
is_student = True
weight = 52.3
hobbies = ["singing","travelling"]
print(f"My name is : {name}\nI'm {age} year old.\nIm student : {is_student}.\nMy weight is : {weight}.\nMy hobbies are: {hobbies}")
# Out:
# My name is : pinal
# I'm 21 year old.
# Im student : True.
# My weight is : 52.3.
# My hobbies are: ['singing', 'travelling']

# %%
#datatypes in python
print(type(name))
print(type(age))
print(type(is_student))
print(type(weight))
print(type(hobbies))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>
# <class 'list'>

# %%
#type casting in python 
x = str(25)
print(x)

y = int("32")
print(y)

z = int(12.67)
print(z)
# Out:
# 25
# 32
# 12
